# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# * CAR PRICE PREDICTION
#
# With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some
# cars are in demand hence making them costly and some are not in demand hence cheaper. One
# of our clients works with small traders, who sell used cars. With the change in market due to covid
# 19 impact, our client is facing problems with their previous car price valuation machine learning
# models. So, they are looking for new machine learning models from new data. We have to make
#
#  * Car price valuation model.
#
#   This project contains two phaseData Collection Phase
#
# You have to scrape at least 5000 used cars data. You can scrape more data as well, it’s up to you.
# more the data better the model
#
# In this section You need to scrape the data of used cars from websites (Olx, cardekho, Cars24
# etc.) You need web scraping for this. You have to fetch data for different locations. The number of
# columns for data doesn’t have limit, it’s up to you and your creativity.
#
# Generally, these columns are
# Brand, model, variant, manufacturing year, driven kilometers, fuel, number of owners, location and
# at last target variable Price of the car. This data is to give you a hint about important variables in
# used car model. You can make changes to it, you can add or you can remove some columns, it
# completely depends on the website from which you are fetching the data.
# Try to include all types of cars in your data for example- SUV, Sedans, Coupe, minivan,
# Hatchback.
#
# * Model Building Phase
#
# After collecting the data, you need to build a machine learning model. Before model building do all
# data pre-processing steps. Try different models with different hyper parameters and select the best
# model.
#
# Follow the complete life cycle of data science. Include all the steps like.
#
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Data Pre-processing
# 4. Model Building
# 5. Model Evaluation
# 6. Selecting the best mode

# %%
# Importing Dataset 
# Reading the excel file

import pandas as pd
import numpy as np

df = pd.read_excel('car_data.xlsx')

# %%
df
# Out:
#       Unnamed: 0     Location                Brand                      Model  \
# 0              0  Maharashtra        Nissan Sunny                          XV
# 1              1  Maharashtra        Skoda Superb                         NaN
# 2              2  Maharashtra              Bmw X5   2007-2013 xDrive 35i 3.0L
# 3              3  Maharashtra       Mahindra Jeep                      Others
# 4              4  Maharashtra         Hyundai I10         2007-2010 Magna 1.2
# ...          ...          ...                  ...                        ...
# 5004        5004      Haryana              Bmw X1          sDrive 20d M Sport
# 5005        5005      Haryana           Ford Figo                      Diesel
# 5006        5006      Haryana       Hyundai Venue           SX Plus Turbo DCT
# 5007        5007      Haryana  Maruti Suzuki Alto                     Vxi 1.1
# 5008        5008      Haryana       Mahindra Thar        LX 4-STR Hard Top AT
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     Location           Brand                      Model  \
# 0           0  Maharashtra   Nissan Sunny                          XV
# 1           1  Maharashtra   Skoda Superb                         NaN
# 2           2  Maharashtra         Bmw X5   2007-2013 xDrive 35i 3.0L
# 3           3  Maharashtra  Mahindra Jeep                      Others
# 4           4  Maharashtra    Hyundai I10         2007-2010 Magna 1.2
#
#   Mnf_year  Driven_kms    Fuel       Gear  Owners   Car_Price
# 0     2012  44584.0 KM  DIESEL     MANUAL     2nd    3,75,000
# 1     2016  27324.0 KM  PETROL  AUTOMATIC      --   13,80,000
# 2     2011   90,000 KM  DIESEL  AUTOMATIC     2nd   17,50,000
# 3     2000    50000 KM  DIESEL     MANUAL  Second    3,00,000
# 4     2008    70000 KM  PETROL     MANUAL   Third    1,35,000

# %%
df.tail()
# Out:
#       Unnamed: 0 Location                Brand                 Model Mnf_year  \
# 5004        5004  Haryana              Bmw X1     sDrive 20d M Sport     2015
# 5005        5005  Haryana           Ford Figo                 Diesel     2013
# 5006        5006  Haryana       Hyundai Venue      SX Plus Turbo DCT     2019
# 5007        5007  Haryana  Maruti Suzuki Alto                Vxi 1.1     2006
# 5008        5008  Haryana       Mahindra Thar   LX 4-STR Hard Top AT     2021
#
#       Driven_kms    Fuel       Gear Owners   Car_Price
# 5004  62000.0 KM  DIESEL  AUTOMATIC    1st   10,37,000
# 5005   85,000 KM  DIESEL     MANUAL    2nd    2,75,000
# 5006  52150.0 KM  DIESEL     MANUAL    1st    9,25,000
# 5007   90,000 KM  PETROL  AUTOMATIC    2nd      89,000
# 5008        0 KM  DIESEL  AUTOMATIC    1st   19,25,000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Location', 'Brand', 'Model', 'Mnf_year', 'Driven_kms',
#        'Fuel', 'Gear', 'Owners', 'Car_Price'],
#       dtype='object')

# %% [markdown]
# # Details about the Columns

# %% [markdown]
# * Location
#
# This Column Shows the Cars Loaction
#
# * Brand
#
# This Column Shows the Cars Brand
#
# * Model
#
# This Column Shows the Cars Model
#
# * Mnf_Year
#
# This Column Shows the Cars Manufacturing Year
#
# * Driven _Kms
#
# This Column Shows the Cars Total Kms Driven
#
# * Fuel
#
# This Column Shows the Cars Fuel Type
#
# * Gear
#
# This Column Shows the Cars Gear System
#
# * Owners
#
# This Column Shows the Cars Owner
#
# * Car Price
#
# This Column Shows the Cars Price

# %% [markdown]
# # Data Exploration

# %%
cat_cols=df.select_dtypes([object])

for col in cat_cols.columns:
    print(col)
    print(df[col].value_counts())
    print('--------------------------------------------------------------------------')
# Out:
# Location
# Telangana        513
# Tamil Nadu       506
# Karnataka        506
# Maharashtra      500
# New Delhi        499
# Haryana          499
# Uttar Pradesh    498
# Punjab           498
# Kerala           497
# Gujrat           493
# Name: Location, dtype: int64
# --------------------------------------------------------------------------
# Brand
# Maruti Suzuki Swift           245
# Maruti Suzuki Swift Dzire     187
# Maruti Suzuki Wagon R         140
# Hyundai I10                   134
# Honda City                    133
#                              ...
# Mini Cooper Clubman             1
# Hyundai Tucson                  1
# Mini Cooper S                   1
# Porsche Macan                   1
# Mercedes Benz Glc Class         1
# Name: Brand, Length: 331, dtype: int64
# --------------------------------------------------------------------------
# Model
# Others                          179
# VXI                             134
# VDI                             120
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Location        0
# Brand           0
# Model         312
# Mnf_year        0
# Driven_kms      0
# Fuel            0
# Gear            0
# Owners          0
# Car_Price       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5009 entries, 0 to 5008
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5009 non-null   int64
#  1   Location    5009 non-null   object
#  2   Brand       5009 non-null   object
#  3   Model       4697 non-null   object
#  4   Mnf_year    5009 non-null   object
#  5   Driven_kms  5009 non-null   object
#  6   Fuel        5009 non-null   object
#  7   Gear        5009 non-null   object
#  8   Owners      5009 non-null   object
#  9   Car_Price   5009 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 391.5+ KB

# %%
df.head()
# Out:
#    Unnamed: 0     Location           Brand                      Model  \
# 0           0  Maharashtra   Nissan Sunny                          XV
# 1           1  Maharashtra   Skoda Superb                         NaN
# 2           2  Maharashtra         Bmw X5   2007-2013 xDrive 35i 3.0L
# 3           3  Maharashtra  Mahindra Jeep                      Others
# 4           4  Maharashtra    Hyundai I10         2007-2010 Magna 1.2
#
#   Mnf_year  Driven_kms    Fuel       Gear  Owners   Car_Price
# 0     2012  44584.0 KM  DIESEL     MANUAL     2nd    3,75,000
# 1     2016  27324.0 KM  PETROL  AUTOMATIC      --   13,80,000
# 2     2011   90,000 KM  DIESEL  AUTOMATIC     2nd   17,50,000
# 3     2000    50000 KM  DIESEL     MANUAL  Second    3,00,000
# 4     2008    70000 KM  PETROL     MANUAL   Third    1,35,000

# %% [markdown]
# Removing the Irellevant Column

# %%
df.drop(["Unnamed: 0"],axis=1, inplace =True)

# %%
df.dtypes
# Out:
# Location      object
# Brand         object
# Model         object
# Mnf_year      object
# Driven_kms    object
# Fuel          object
# Gear          object
# Owners        object
# Car_Price     object
# dtype: object

# %%
# This will check the duplicate data for all columns.

df.duplicated().sum()
# Out:
# 158

# %%
#Checking null values in the dataset

df.isnull().sum().any()
# Out:
# True

# %%
df.isin(['--']).sum()
# Out:
# Location        0
# Brand           0
# Model           0
# Mnf_year        0
# Driven_kms      0
# Fuel           37
# Gear          177
# Owners        205
# Car_Price       0
# dtype: int64

# %%
df.isin(['-']).sum()
# Out:
# Location        0
# Brand         107
# Model         107
# Mnf_year      107
# Driven_kms    107
# Fuel          107
# Gear          107
# Owners        107
# Car_Price     107
# dtype: int64

# %%
df['Driven_kms']=df['Driven_kms'].apply(lambda x: x.replace(',','') if x!='-' else '-')
df.head()
# Out:
#       Location           Brand                      Model Mnf_year  \
# 0  Maharashtra   Nissan Sunny                          XV     2012
# 1  Maharashtra   Skoda Superb                         NaN     2016
# 2  Maharashtra         Bmw X5   2007-2013 xDrive 35i 3.0L     2011
# 3  Maharashtra  Mahindra Jeep                      Others     2000
# 4  Maharashtra    Hyundai I10         2007-2010 Magna 1.2     2008
#
#    Driven_kms    Fuel       Gear  Owners   Car_Price
# 0  44584.0 KM  DIESEL     MANUAL     2nd    3,75,000
# 1  27324.0 KM  PETROL  AUTOMATIC      --   13,80,000
# 2    90000 KM  DIESEL  AUTOMATIC     2nd   17,50,000
# 3    50000 KM  DIESEL     MANUAL  Second    3,00,000
# 4    70000 KM  PETROL     MANUAL   Third    1,35,000

# %%
#Removing km word from km_driven

df['Driven_kms']=df['Driven_kms'].apply(lambda x: x.split(' ')[0] if x!='-' else 0)

#Checking the dataset after removing

df.head()
# Out:
#       Location           Brand                      Model Mnf_year Driven_kms  \
# 0  Maharashtra   Nissan Sunny                          XV     2012    44584.0
# 1  Maharashtra   Skoda Superb                         NaN     2016    27324.0
# 2  Maharashtra         Bmw X5   2007-2013 xDrive 35i 3.0L     2011      90000
# 3  Maharashtra  Mahindra Jeep                      Others     2000      50000
# 4  Maharashtra    Hyundai I10         2007-2010 Magna 1.2     2008      70000
#
#      Fuel       Gear  Owners   Car_Price
# 0  DIESEL     MANUAL     2nd    3,75,000
# 1  PETROL  AUTOMATIC      --   13,80,000
# 2  DIESEL  AUTOMATIC     2nd   17,50,000
# 3  DIESEL     MANUAL  Second    3,00,000
# 4  PETROL     MANUAL   Third    1,35,000

# %%
df['Driven_kms']=df['Driven_kms'].astype(float)

# %%
df['Driven_kms']=df['Driven_kms'].replace('-','90000.0')

# %%
df['Car_Price']=df['Car_Price'].apply(lambda x: x.replace(',','') if x!='-' else '-')

df.head()
# Out:
#       Location           Brand                      Model Mnf_year  \
# 0  Maharashtra   Nissan Sunny                          XV     2012
# 1  Maharashtra   Skoda Superb                         NaN     2016
# 2  Maharashtra         Bmw X5   2007-2013 xDrive 35i 3.0L     2011
# 3  Maharashtra  Mahindra Jeep                      Others     2000
# 4  Maharashtra    Hyundai I10         2007-2010 Magna 1.2     2008
#
#    Driven_kms    Fuel       Gear  Owners Car_Price
# 0     44584.0  DIESEL     MANUAL     2nd    375000
# 1     27324.0  PETROL  AUTOMATIC      --   1380000
# 2     90000.0  DIESEL  AUTOMATIC     2nd   1750000
# 3     50000.0  DIESEL     MANUAL  Second    300000
# 4     70000.0  PETROL     MANUAL   Third    135000

# %%
df['Car_Price']=df['Car_Price'].replace('-',' 325000')

# %%
df['Car_Price']=df['Car_Price'].str.strip()

# %%
df['Car_Price']=df['Car_Price'].astype(float)

# %%
df.info
# Out:
# <bound method DataFrame.info of          Location                Brand                      Model Mnf_year  \
# 0     Maharashtra        Nissan Sunny                          XV     2012
# 1     Maharashtra        Skoda Superb                         NaN     2016
# 2     Maharashtra              Bmw X5   2007-2013 xDrive 35i 3.0L     2011
# 3     Maharashtra       Mahindra Jeep                      Others     2000
# 4     Maharashtra         Hyundai I10         2007-2010 Magna 1.2     2008
# ...           ...                  ...                        ...      ...
# 5004      Haryana              Bmw X1          sDrive 20d M Sport     2015
# 5005      Haryana           Ford Figo                      Diesel     2013
# 5006      Haryana       Hyundai Venue           SX Plus Turbo DCT     2019
# 5007      Haryana  Maruti Suzuki Alto                     Vxi 1.1     2006
# 5008      Haryana       Mahindra Thar        LX 4-STR Hard Top AT     2021
#
# ...

# %%
df['Owners'].unique()
# Out:
# array(['2nd', '--', 'Second', 'Third', '1st', '3rd', 'First', 'Fourth',
#        '4th', '-', '4+'], dtype=object)

# %%
df['Owners']=df['Owners'].replace('Second','2nd')

# %%
df['Owners']=df['Owners'].replace('First','1st')

# %%
df['Owners']=df['Owners'].replace('Third','3rd')

# %%
df['Owners']=df['Owners'].replace('Fourth','4th')

# %%
df['Owners']=df['Owners'].replace('--','-')

# %%
df['Owners'].unique()
# Out:
# array(['2nd', '-', '3rd', '1st', '4th', '4+'], dtype=object)

# %%
df['Owners'].value_counts()
# Out:
# 1st    2760
# 2nd    1431
# 3rd     381
# -       312
# 4th      96
# 4+       29
# Name: Owners, dtype: int64

# %%
df['Owners']=df['Owners'].replace('-','1st')

# %%
df['Gear'].mode()
# Out:
# 0    MANUAL
# dtype: object

# %%
df['Gear']=df['Gear'].replace('-','MANUAL')

# %%
df['Gear']=df['Gear'].replace('--','MANUAL')

# %%
df['Gear'].value_counts()
# Out:
# MANUAL       4068
# AUTOMATIC     941
# Name: Gear, dtype: int64

# %%
df['Fuel'].value_counts()
# Out:
# DIESEL                           2547
# PETROL                           2018
# CNG & HYBRIDS                     195
# -                                 107
# CNG                                67
# --                                 37
# LPG                                31
# ELECTRIC                            6
# PETROL/COMPRESSED NATURAL GAS       1
# Name: Fuel, dtype: int64

# %%
df['Fuel']=df['Fuel'].replace('--','DIESEL')

df['Fuel']=df['Fuel'].replace('-','DIESEL')

df['Fuel'].value_counts()
# Out:
# DIESEL                           2691
# PETROL                           2018
# CNG & HYBRIDS                     195
# CNG                                67
# LPG                                31
# ELECTRIC                            6
# PETROL/COMPRESSED NATURAL GAS       1
# Name: Fuel, dtype: int64

# %%
df['Mnf_year'].value_counts()
# Out:
# 2012      448
# 2013      437
# 2016      408
# 2014      404
# 2015      386
# 2011      376
# 2017      371
# 2018      369
# 2010      321
# 2009      223
# 2019      215
# 2007      178
# 2008      171
# 2020      129
# -         107
# 2006      105
# 2021       87
# 2005       61
# 2004       40
# 2003       31
# 2002       26
# 2000       21
# 1998       15
# 2001       14
# 1999       13
# 1997        8
# 2015.0      6
# 1996        6
# 2012.0      4
# 2016.0      4
# 1994        4
# 1995        3
# 2017.0      3
# 2014.0      3
# 2013.0      2
# 2011.0      2
# 1992        1
# 1990        1
# 1954        1
# 1988        1
# 1981        1
# 1991        1
# 1993        1
# 1905        1
# Name: Mnf_year, dtype: int64

# %%
df['Mnf_year']=df['Mnf_year'].replace('2015.0','2015')

df['Mnf_year']=df['Mnf_year'].replace('2012.0','2012')

df['Mnf_year']=df['Mnf_year'].replace('2016.0','2016')

df['Mnf_year']=df['Mnf_year'].replace('2017.0','2017')

df['Mnf_year']=df['Mnf_year'].replace('2014.0','2014')

df['Mnf_year']=df['Mnf_year'].replace('2013.0','2013')

df['Mnf_year']=df['Mnf_year'].replace('2011.0','2011')

df['Mnf_year'].value_counts()
# Out:
# 2012    452
# 2013    439
# 2016    412
# 2014    407
# 2015    392
# 2011    378
# 2017    374
# 2018    369
# 2010    321
# 2009    223
# 2019    215
# 2007    178
# 2008    171
# 2020    129
# -       107
# 2006    105
# 2021     87
# 2005     61
# 2004     40
# 2003     31
# 2002     26
# 2000     21
# 1998     15
# 2001     14
# 1999     13
# 1997      8
# 1996      6
# 1994      4
# 1995      3
# 1988      1
# 1993      1
# 1991      1
# 1981      1
# 1990      1
# 1992      1
# 1954      1
# 1905      1
# Name: Mnf_year, dtype: int64

# %%
df['Mnf_year']=df['Mnf_year'].replace('-','2012')

# %%
df['Model'].value_counts()
# Out:
# Others                          179
# VXI                             134
# VDI                             120
# -                               107
# LXI                              92
#                                ...
# 2.0 LXd                           1
# King Hard Top BSII                1
# Asta Option Diesel                1
# 2014-2016 1.1 CRDi SX Option      1
# LX 4-STR Hard Top AT              1
# Name: Model, Length: 1697, dtype: int64

# %%
df['Model']=df['Model'].replace('-','Others')

# %%
df['Brand'].mode()
# Out:
# 0    Maruti Suzuki Swift
# dtype: object

# %%
df['Brand']=df['Brand'].replace('-','Maruti Suzuki Swift')

# %%
df.isin(['-']).sum()
# Out:
# Location      0
# Brand         0
# Model         0
# Mnf_year      0
# Driven_kms    0
# Fuel          0
# Gear          0
# Owners        0
# Car_Price     0
# dtype: int64

# %%
df.isin(['--']).sum()
# Out:
# Location      0
# Brand         0
# Model         0
# Mnf_year      0
# Driven_kms    0
# Fuel          0
# Gear          0
# Owners        0
# Car_Price     0
# dtype: int64

# %%
df.describe(include=['O'])
# Out:
#          Location                 Brand   Model Mnf_year    Fuel    Gear  \
# count        5009                  5009    4697     5009    5009    5009
# unique         10                   331    1696       36       7       2
# top     Telangana  Maruti Suzuki Swift   Others     2012  DIESEL  MANUAL
# freq          513                   245     286      559    2691    4068
#
#        Owners
# count    5009
# unique      5
# top       1st
# freq     3072

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

list1=['Location','Brand','Model','Mnf_year','Fuel','Gear','Owners']
for val in list1:
  df[val]=le.fit_transform(df[val].astype(str))

# %% [markdown]
# # Explotary Data Anaysis

# %%
import matplotlib.pyplot as plt

group = "Gear"
target = "Fuel"
fig, ax = plt.subplots(figsize = (12,15))
temp_df = (df.groupby([group, target]).size()/df.groupby(group)[target].count()).reset_index().pivot(columns=target, index=group, values=0)
temp_df.plot(kind='bar', stacked=True, ax = ax, color = ["green", "darkred","blue","yellow","Seagreen","pink","orange"])
ax.xaxis.set_tick_params(rotation=0)
ax.set_xlabel(group)
ax.set_ylabel('Comparission of');

# %%
import seaborn as sns
sns.scatterplot(df['Driven_kms'],df['Car_Price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Fuel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['Gear'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(16,8))
sns.countplot(x="Mnf_year", hue="Gear", data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
df.hist(figsize=(15,30),edgecolor='red',layout=(9,3),bins=15,legend=True)
plt.show()

# %% [markdown]
# # Coorelation

# %%
df.corr()
# Out:
#             Location     Brand     Model  Mnf_year  Driven_kms      Fuel  \
# Location    1.000000  0.030459 -0.006347 -0.051605    0.048147 -0.016600
# Brand       0.030459  1.000000  0.006848  0.037811    0.074986 -0.096574
# Model      -0.006347  0.006848  1.000000  0.063230   -0.075070 -0.009705
# Mnf_year   -0.051605  0.037811  0.063230  1.000000   -0.246247 -0.092100
# Driven_kms  0.048147  0.074986 -0.075070 -0.246247    1.000000 -0.148559
# Fuel       -0.016600 -0.096574 -0.009705 -0.092100   -0.148559  1.000000
# Gear        0.014443  0.066261  0.029066 -0.124779    0.054478  0.011869
# Owners     -0.019139 -0.002949 -0.095492 -0.445798    0.192564 -0.021299
# Car_Price  -0.012986  0.024839  0.027652  0.338017   -0.116693 -0.128330
#
#                 Gear    Owners  Car_Price
# Location    0.014443 -0.019139  -0.012986
# Brand       0.066261 -0.002949   0.024839
# Model       0.029066 -0.095492   0.027652
# Mnf_year   -0.124779 -0.445798   0.338017
# ...

# %%
df.corr()['Car_Price'].sort_values()
# Out:
# Gear         -0.420162
# Owners       -0.154587
# Fuel         -0.128330
# Driven_kms   -0.116693
# Location     -0.012986
# Brand         0.024839
# Model         0.027652
# Mnf_year      0.338017
# Car_Price     1.000000
# Name: Car_Price, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#           Location        Brand        Model     Mnf_year     Driven_kms  \
# count  5009.000000  5009.000000  5009.000000  5009.000000    5009.000000
# mean      4.514474   164.027151   981.630465    26.997804   74368.272509
# std       2.870932    82.494167   534.949223     4.477780   69551.009349
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       2.000000    98.000000   497.000000    25.000000   44000.000000
# 50%       5.000000   166.000000  1111.000000    27.000000   68585.000000
# 75%       7.000000   195.000000  1462.000000    30.000000   90000.000000
# max       9.000000   330.000000  1696.000000    35.000000  999999.000000
#
#               Fuel         Gear       Owners     Car_Price
# count  5009.000000  5009.000000  5009.000000  5.009000e+03
# mean      3.157317     0.812138     0.531843  6.580769e+05
# std       1.551951     0.390641     0.816069  1.069831e+06
# min       0.000000     0.000000     0.000000  1.500000e+04
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5009 entries, 0 to 5008
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    5009 non-null   int64
#  1   Brand       5009 non-null   int64
#  2   Model       5009 non-null   int64
#  3   Mnf_year    5009 non-null   int64
#  4   Driven_kms  5009 non-null   float64
#  5   Fuel        5009 non-null   int64
#  6   Gear        5009 non-null   int64
#  7   Owners      5009 non-null   int64
#  8   Car_Price   5009 non-null   float64
# dtypes: float64(2), int64(7)
# memory usage: 352.3 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5009 entries, 0 to 5008
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    5009 non-null   int64
#  1   Brand       5009 non-null   int64
#  2   Model       5009 non-null   int64
#  3   Mnf_year    5009 non-null   int64
#  4   Driven_kms  5009 non-null   float64
#  5   Fuel        5009 non-null   int64
#  6   Gear        5009 non-null   int64
#  7   Owners      5009 non-null   int64
#  8   Car_Price   5009 non-null   float64
# dtypes: float64(2), int64(7)
# memory usage: 352.3 KB

# %% [markdown]
# # Checking Data To Remove Skewness

# %%
df.head()
# Out:
#    Location  Brand  Model  Mnf_year  Driven_kms  Fuel  Gear  Owners  Car_Price
# 0         4    238   1625        26     44584.0     2     1       1   375000.0
# 1         4    263   1687        30     27324.0     5     0       0  1380000.0
# 2         4     26    486        25     90000.0     2     0       1  1750000.0
# 3         4    140   1335        14     50000.0     2     1       1   300000.0
# 4         4    100    467        22     70000.0     5     1       2   135000.0

# %%
df.iloc[:,:-1].skew()
# Out:
# Location     -0.006190
# Brand         0.255143
# Model        -0.360565
# Mnf_year     -0.886255
# Driven_kms    7.600205
# Fuel          0.236734
# Gear         -1.598721
# Owners        1.959504
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(df.iloc[:,:-1],method='yeo-johnson')

df.iloc[:,:-1]=pd.DataFrame(x_new,columns=df.iloc[:,:-1].columns)

# %%
df.iloc[:,:-1].skew()
# Out:
# Location     -0.043066
# Brand        -0.011153
# Model        -0.119881
# Mnf_year     -0.030428
# Driven_kms    0.353675
# Fuel         -0.129482
# Gear         -1.598721
# Owners        0.515660
# dtype: float64

# %%
for col in df.iloc[:,:-1].columns:
    sns.distplot(df.iloc[:,:-1][col])
    plt.show()

# %% [markdown]
# # Out Liers Checking

# %%
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(5,2), figsize=[20,8])
# Out:
# Location         AxesSubplot(0.125,0.749828;0.352273x0.130172)
# Brand         AxesSubplot(0.547727,0.749828;0.352273x0.130172)
# Model            AxesSubplot(0.125,0.593621;0.352273x0.130172)
# Mnf_year      AxesSubplot(0.547727,0.593621;0.352273x0.130172)
# Driven_kms       AxesSubplot(0.125,0.437414;0.352273x0.130172)
# Fuel          AxesSubplot(0.547727,0.437414;0.352273x0.130172)
# Gear             AxesSubplot(0.125,0.281207;0.352273x0.130172)
# Owners        AxesSubplot(0.547727,0.281207;0.352273x0.130172)
# Car_Price           AxesSubplot(0.125,0.125;0.352273x0.130172)
# dtype: object

# %% [markdown]
# # IQR Proximity Rule
# Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (5009, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  43,  123,  132,  135,  142,  183,  185,  244,  263,  304,  344,
#         355,  384,  403,  423,  424,  444,  455,  483,  484,  645,  926,
#         965,  986, 1037, 1070, 1087, 1090, 1097, 1110, 1130, 1131, 1132,
#        1142, 1143, 1144, 1150, 1170, 1175, 1176, 1177, 1200, 1201, 1202,
#        1203, 1221, 1222, 1224, 1237, 1247, 1248, 1250, 1266, 1268, 1269,
#        1272, 1273, 1299, 1300, 1308, 1309, 1328, 1329, 1367, 1384, 1389,
#        1397, 1447, 1475, 1587, 1601, 1630, 1707, 1725, 1761, 1764, 1825,
#        1846, 1904, 1935, 1935, 1942, 1966, 1974, 2005, 2044, 2111, 2116,
#        2124, 2143, 2144, 2180, 2203, 2204, 2223, 2253, 2271, 2282, 2288,
#        2293, 2324, 2325, 2341, 2343, 2344, 2351, 2360, 2363, 2391, 2402,
#        2424, 2437, 2440, 2463, 2466, 2471, 2475, 2544, 2583, 2591, 2595,
#        2665, 2677, 2721, 2793, 2832, 2840, 2898, 2899, 2920, 2935, 2989,
#        3025, 3031, 3040, 3050, 3056, 3067, 3071, 3079, 3084, 3107, 3126,
# ...

# %%
len(np.where(z>3)[0])
# Out:
# 195

# %%
df.drop([43,  123,  132,  135,  142,  183,  185,  244,  263,  304,  344,
        355,  384,  403,  423,  424,  444,  455,  483,  484,  645,  926,
        965,  986, 1037, 1070, 1087, 1090, 1097, 1110, 1130, 1131, 1132,
       1142, 1143, 1144, 1150, 1170, 1175, 1176, 1177, 1200, 1201, 1202,
       1203, 1221, 1222, 1224, 1237, 1247, 1248, 1250, 1266, 1268, 1269,
       1272, 1273, 1299, 1300, 1308, 1309, 1328, 1329, 1367, 1384, 1389,
       1397, 1447, 1475, 1587, 1601, 1630, 1707, 1725, 1761, 1764, 1825,
       1846, 1904, 1935, 1935, 1942, 1966, 1974, 2005, 2044, 2111, 2116,
       2124, 2143, 2144, 2180, 2203, 2204, 2223, 2253, 2271, 2282, 2288,
       2293, 2324, 2325, 2341, 2343, 2344, 2351, 2360, 2363, 2391, 2402,
       2424, 2437, 2440, 2463, 2466, 2471, 2475, 2544, 2583, 2591, 2595,
       2665, 2677, 2721, 2793, 2832, 2840, 2898, 2899, 2920, 2935, 2989,
       3025, 3031, 3040, 3050, 3056, 3067, 3071, 3079, 3084, 3107, 3126,
       3127, 3207, 3266, 3306, 3307, 3326, 3346, 3366, 3427, 3455, 3462,
       3463, 3482, 3483, 3542, 3548, 3655, 3865, 3871, 3944, 4021, 4122,
       4157, 4199, 4297, 4359, 4386, 4419, 4430, 4456, 4474, 4520, 4525,
       4539, 4542, 4563, 4566, 4582, 4624, 4632, 4706, 4712, 4792, 4809,
       4813, 4832, 4845, 4864, 4893, 4911, 4932, 4972],axis=0)
# Out:
#       Location     Brand     Model  Mnf_year  Driven_kms      Fuel      Gear  \
# 0    -0.167780  0.899475  1.316280 -0.352193   -0.391631 -0.667638  0.480955
# 1    -0.167780  1.171337  1.477252  0.655454   -0.859182  1.140708 -2.079197
# 2    -0.167780 -1.846463 -0.954015 -0.573142    0.480252 -0.667638 -2.079197
# 3    -0.167780 -0.229666  0.606905 -2.288541   -0.266992 -0.667638  0.480955
# 4    -0.167780 -0.732514 -0.981941 -1.167065    0.137069  1.140708  0.480955
# ...        ...       ...       ...       ...         ...       ...       ...
# 5004 -1.215959 -1.903328  1.479874  0.384440   -0.015592 -0.667638 -2.079197
# 5005 -1.215959 -1.170596  0.094959 -0.119210    0.398848 -0.667638  0.480955
# 5006 -1.215959 -0.628770  0.850171  1.546394   -0.219634 -0.667638  0.480955
# 5007 -1.215959  0.045706  1.203926 -1.508225    0.480252  1.140708 -2.079197
# 5008 -1.215959 -0.073104  0.474502  2.206433   -2.823640 -0.667638 -2.079197
#
#         Owners  Car_Price
# ...

# %%
df=df[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (4815, 9)

# %%
df.isnull().sum()
# Out:
# Location      0
# Brand         0
# Model         0
# Mnf_year      0
# Driven_kms    0
# Fuel          0
# Gear          0
# Owners        0
# Car_Price     0
# dtype: int64

# %% [markdown]
# # Feature Engineering ( Variantion Inflation Factor )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.corr()
# Out:
#             Location     Brand     Model  Mnf_year  Driven_kms      Fuel  \
# Location    1.000000  0.026093 -0.015820 -0.060390    0.046950 -0.016719
# Brand       0.026093  1.000000  0.022171  0.035767    0.067749 -0.089385
# Model      -0.015820  0.022171  1.000000  0.084008   -0.150777 -0.001116
# Mnf_year   -0.060390  0.035767  0.084008  1.000000   -0.374822 -0.067322
# Driven_kms  0.046950  0.067749 -0.150777 -0.374822    1.000000 -0.179783
# Fuel       -0.016719 -0.089385 -0.001116 -0.067322   -0.179783  1.000000
# Gear        0.021728  0.093615  0.054359 -0.091983    0.046774 -0.003407
# Owners      0.002943 -0.003896 -0.111787 -0.439501    0.294456 -0.007939
# Car_Price  -0.066152 -0.005899 -0.044277  0.466825   -0.127894 -0.203803
#
#                 Gear    Owners  Car_Price
# Location    0.021728  0.002943  -0.066152
# Brand       0.093615 -0.003896  -0.005899
# Model       0.054359 -0.111787  -0.044277
# Mnf_year   -0.091983 -0.439501   0.466825
# ...

# %%
plt.figure(figsize=(25,22))
sns.heatmap(df.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.2g', annot = True, linecolor="black",annot_kws={'size':15},cmap="YlGnBu")
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# Splitting the Dataset and removing the Target Columns

# %%
x=df.drop('Car_Price',axis=1)
y=df['Car_Price']

# %%
x
# Out:
#       Location     Brand     Model  Mnf_year  Driven_kms      Fuel      Gear  \
# 0    -0.167780  0.899475  1.316280 -0.352193   -0.391631 -0.667638  0.480955
# 1    -0.167780  1.171337  1.477252  0.655454   -0.859182  1.140708 -2.079197
# 2    -0.167780 -1.846463 -0.954015 -0.573142    0.480252 -0.667638 -2.079197
# 3    -0.167780 -0.229666  0.606905 -2.288541   -0.266992 -0.667638  0.480955
# 4    -0.167780 -0.732514 -0.981941 -1.167065    0.137069  1.140708  0.480955
# ...        ...       ...       ...       ...         ...       ...       ...
# 5004 -1.215959 -1.903328  1.479874  0.384440   -0.015592 -0.667638 -2.079197
# 5005 -1.215959 -1.170596  0.094959 -0.119210    0.398848 -0.667638  0.480955
# 5006 -1.215959 -0.628770  0.850171  1.546394   -0.219634 -0.667638  0.480955
# 5007 -1.215959  0.045706  1.203926 -1.508225    0.480252  1.140708 -2.079197
# 5008 -1.215959 -0.073104  0.474502  2.206433   -2.823640 -0.667638 -2.079197
#
#         Owners
# 0     1.134907
# ...

# %%
y
# Out:
# 0        375000.0
# 1       1380000.0
# 2       1750000.0
# 3        300000.0
# 4        135000.0
#           ...
# 5004    1037000.0
# 5005     275000.0
# 5006     925000.0
# 5007      89000.0
# 5008    1925000.0
# Name: Car_Price, Length: 4815, dtype: float64

# %%
def vif_calc():
  vif=pd.DataFrame()
  vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
  vif["features"]=x.columns
  print(vif)

# %%
vif_calc()
# Out:
#    VIF Factor    features
# 0    1.006452    Location
# 1    1.024627       Brand
# 2    1.033645       Model
# 3    1.399409    Mnf_year
# 4    1.278323  Driven_kms
# 5    1.063235        Fuel
# 6    1.025783        Gear
# 7    1.281153      Owners

# %% [markdown]
# We can see that the Vif Values of all the Columns are below 10 so we dont need any changes

# %% [markdown]
# # Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#       Location     Brand     Model  Mnf_year  Driven_kms     Fuel      Gear  \
# 0    -0.167345  0.901609  1.309715 -0.338465   -0.409884 -0.76177  0.457042
# 1    -0.167345  1.174860  1.469125  0.681812   -0.928216  1.15791 -2.187981
# 2    -0.167345 -1.858369 -0.938548 -0.562183    0.556695 -0.76177 -2.187981
# 3    -0.167345 -0.233306  0.607224 -2.299082   -0.271708 -0.76177  0.457042
# 4    -0.167345 -0.738725 -0.966203 -1.163550    0.176239  1.15791  0.457042
# ...        ...       ...       ...       ...         ...      ...       ...
# 4810 -1.220719 -1.915525  1.471721  0.407402    0.006997 -0.76177 -2.187981
# 4811 -1.220719 -1.179047  0.100246 -0.102561    0.466450 -0.76177  0.457042
# 4812 -1.220719 -0.634450  0.848129  1.583919   -0.219206 -0.76177  0.457042
# 4813 -1.220719  0.043474  1.198451 -1.508986    0.556695  1.15791 -2.187981
# 4814 -1.220719 -0.075944  0.476106  2.252231   -3.106035 -0.76177 -2.187981
#
#         Owners
# 0     1.133566
# 1    -0.790876
# ...

# %% [markdown]
# # MODELLING FOR CAr Price
# # Building Regression Model As Target Column Datatype is Float

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Modelling
# # Getting the best random state

# %%
#gettig the best random state
maxAccu=0
maxRS=0
for i in range(1,100): 
    x_train,x_test, y_train, y_test =train_test_split(x,y, test_size=.30,random_state=i)
    mod=RandomForestRegressor()
    mod.fit(x_train, y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('R2 Score=', maxAccu*100, 'Random_State',maxRS)
# Out:
# R2 Score= 81.86002553575963 Random_State 71

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=.30, random_state=maxRS)

# %% [markdown]
# # Linear Regression

# %%
# Checking r2score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

# prediction
predLR=LR.predict(x_test)
print('R2_score:',(r2_score(y_test,predLR))*100)

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predLR))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predLR))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 42.71833221276439
# MAE: 245616.81538581173
# MSE: 161793358145.27963
# RMSE: 402235.45112940954

# %% [markdown]
# # Random Forest Regressor

# %%
rf=RandomForestRegressor()
rf.fit(x_train, y_train)

# prediction
predrf=rf.predict(x_test)
print('R2_score:',(r2_score(y_test,predrf))*100)

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predrf))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predrf))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predrf)))
# Out:
# R2_score: 81.86342531400861
# MAE: 126130.77010855166
# MSE: 51227162843.76589
# RMSE: 226334.18399297507

# %% [markdown]
# # Gradient Boosting Regressor

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)

predgb=gb.predict(x_test)
print('R2_Score:',(r2_score(y_test,predgb))*100)

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predgb))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predgb))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predgb)))
# Out:
# R2_Score: 76.35547231673891
# MAE: 148474.416060937
# MSE: 66784499882.98531
# RMSE: 258426.97205010414

# %% [markdown]
# # Bagging Regressor

# %%
br=BaggingRegressor()
br.fit(x_train,y_train)

predbr=br.predict(x_test)
print('R2_Score:',(r2_score(y_test,predbr))*100)

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predbr))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predbr))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predbr)))
# Out:
# R2_Score: 80.93091248268165
# MAE: 130725.47815455594
# MSE: 53861066295.29163
# RMSE: 232079.87050860666

# %% [markdown]
# # Cross- Validation

# %%
# Checking cv score for Linear Regression
print(cross_val_score(LR,x,y,cv=5).mean()*100)

# Checking cv score for Random Forest Regressor
print(cross_val_score(rf,x,y,cv=5).mean()*100)

#Checking the cv score for GradientBoostingRegressor
print(cross_val_score(gb,x,y,cv=5).mean()*100)

#Checking the cv score for BaggingRegressor
print(cross_val_score(br,x,y,cv=5).mean()*100)
# Out:
# 40.65685873620928
# 75.0931581182331
# 72.41402525481433
# 71.71903385165564

# %% [markdown]
# From the accuracy score and cross validation we can see that Random Forest Regressor is the best model.

# %% [markdown]
# # Hyper Parameter Tuning for the model with best acc and cv score

# %%
#RandomForestRegressor
parameters = {'criterion':['mse', 'mae'],
             'max_features':['auto', 'sqrt', 'log2'],
             'n_estimators':[0,200],
             'max_depth':[2,3,4,6]}

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 3, 4, 6],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [0, 200]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
Price = RandomForestRegressor(criterion='mae', max_depth=6, max_features='auto', n_estimators=200)
Price.fit(x_train, y_train)
pred = Price.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, predrf)))
# Out:
# R2_Score: 63.13866121674394
# RMSE value: 226334.18399297507

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(Price,"Rainfall_Amount_Prediction.pkl")

# %% [markdown]
# # Final Accuracy Rate is 82%
